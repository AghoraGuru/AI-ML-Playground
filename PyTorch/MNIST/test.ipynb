# %%
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

import seaborn as sns

# %%
df = pd.read_excel("/home/kalyan/Desktop/Class Morks (1).xlsx", sheet_name="Sheet1")

# %%
df
# Out:
#                          Name              Roll    BDA  DAA  ICN   ROS  MIS
# 0                   Abinaya N  CB.EN.U4AIE21001  33.97   35   79  47.4   50
# 1                Akshayaa B K  CB.EN.U4AIE21002  39.42   28   70  41.0   39
# 2                 Aman Sirohi  CB.EN.U4AIE21003  60.63   41   91  54.1   60
# 3                 Arin Ghorui  CB.EN.U4AIE21004  35.49   34   65  45.0   40
# 4         ATUKURI S M DINAKAR  CB.EN.U4AIE21005  20.98   24   53  35.7   37
# ..                        ...               ...    ...  ...  ...   ...  ...
# 150              Vigneshwar E  CB.EN.U4AIE21175  16.04   30   45  33.6   38
# 151  VORUVURU SISIR KAUSTHUBH  CB.EN.U4AIE21176  18.64   23   51  29.0   45
# 152              Vura Abhinav  CB.EN.U4AIE21177  35.94   34   58  42.2   55
# 153           Yalavarthi Hima  CB.EN.U4AIE21178  34.71   31   66  35.1   49
# 154     Yeturu Shashank Reddy  CB.EN.U4AIE21179  27.64   22   47  42.7   48
#
# [155 rows x 7 columns]

# %%
# Columns indexing from 3 to end
df.iloc[:, 2:]
# Out:
#        BDA  DAA  ICN   ROS  MIS
# 0    33.97   35   79  47.4   50
# 1    39.42   28   70  41.0   39
# 2    60.63   41   91  54.1   60
# 3    35.49   34   65  45.0   40
# 4    20.98   24   53  35.7   37
# ..     ...  ...  ...   ...  ...
# 150  16.04   30   45  33.6   38
# 151  18.64   23   51  29.0   45
# 152  35.94   34   58  42.2   55
# 153  34.71   31   66  35.1   49
# 154  27.64   22   47  42.7   48
#
# [155 rows x 5 columns]

# %%
temp = df.iloc[:, 2:]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    155 non-null    object
#  1   Roll    155 non-null    object
#  2   BDA     155 non-null    float64
#  3   DAA     155 non-null    int64
#  4   ICN     155 non-null    int64
#  5   ROS     155 non-null    float64
#  6   MIS     155 non-null    int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 8.6+ KB

# %%
sns.pairplot(temp, diag_kind="kde", corner=False)

# %%
# Check how much deviated from normal distribution
temp.skew()
# Out:
# BDA    0.446123
# DAA    0.317778
# ICN    0.012830
# ROS    0.488396
# MIS   -0.273907
# dtype: float64

# %%
# Plot normal distribution vs actual distribution for each column

for i in temp.columns:
    sns.distplot(temp[i])
    plt.show()
# Out:
# /tmp/ipykernel_13401/3180433416.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(temp[i])
# /tmp/ipykernel_13401/3180433416.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(temp[i])
# /tmp/ipykernel_13401/3180433416.py:4: UserWarning:
#
# ...
